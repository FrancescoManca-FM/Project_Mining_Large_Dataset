# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import fpgrowth
#from kmodes.kmodes import KPrototypes

# %% [markdown]
# # Customer Personality Analysis Dataset

# %% [markdown]
# Load dataset

# %%
df = pd.read_csv("./marketing_campaign.csv",delimiter="\t")
df.head()
df.drop(columns=["ID"], inplace=True)

# %%
df.info()
education = np.apply_along_axis(lambda x : "Education_"+x, axis=0, arr=df["Education"].unique())
marital_status = np.apply_along_axis(lambda x : "Marital_Status_"+x, axis=0, arr=df["Marital_Status"].unique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year_Birth           2240 non-null   int64
#  1   Education            2240 non-null   object
#  2   Marital_Status       2240 non-null   object
#  3   Income               2216 non-null   float64
#  4   Kidhome              2240 non-null   int64
#  5   Teenhome             2240 non-null   int64
#  6   Dt_Customer          2240 non-null   object
#  7   Recency              2240 non-null   int64
#  8   MntWines             2240 non-null   int64
#  9   MntFruits            2240 non-null   int64
#  10  MntMeatProducts      2240 non-null   int64
#  11  MntFishProducts      2240 non-null   int64
#  12  MntSweetProducts     2240 non-null   int64
#  13  MntGoldProds         2240 non-null   int64
#  14  NumDealsPurchases    2240 non-null   int64
#  15  NumWebPurchases      2240 non-null   int64
#  16  NumCatalogPurchases  2240 non-null   int64
#  17  NumStorePurchases    2240 non-null   int64
#  18  NumWebVisitsMonth    2240 non-null   int64
#  19  AcceptedCmp3         2240 non-null   int64
#  20  AcceptedCmp4         2240 non-null   int64
#  21  AcceptedCmp5         2240 non-null   int64
#  22  AcceptedCmp1         2240 non-null   int64
#  23  AcceptedCmp2         2240 non-null   int64
#  24  Complain             2240 non-null   int64
#  25  Z_CostContact        2240 non-null   int64
#  26  Z_Revenue            2240 non-null   int64
#  27  Response             2240 non-null   int64
# dtypes: float64(1), int64(24), object(3)
# memory usage: 490.1+ KB

# %%
#removing duplicates
df.drop_duplicates(inplace=True)

# %%
#removing column year of birth and creating a column age ( age of each person in the moment he/she enroll)
df["age"] = (df["Dt_Customer"].apply(lambda x : x.split("-")[2]).astype(int)).to_numpy()-df["Year_Birth"].to_numpy()
df.drop(columns=["Year_Birth", "Dt_Customer"], inplace=True)

# %%
df["Marital_Status"].replace(to_replace=["Together","Married"], value = "couple",inplace=True)
df["Marital_Status"].replace(to_replace=["Single","Divorced","Widow"], value = "single",inplace=True)
df['Children']=df['Kidhome']+df['Teenhome']
df['Has_child'] = np.where(df.Children > 0, 'yes', 'no')
df['Education']=df['Education'].replace({'Basic':'Undergraduate','2n Cycle':'Undergraduate','Graduation':'Postgraduate','Master':'Postgraduate','PhD':'Postgraduate'})

# %% [markdown]
# The dataset has $2058$ fields. We have some missing values for the attribute "Income". We can keep them. We only remove when we consider the attribute income in our analysis.

# %%
df.dropna(inplace=True)

# %% [markdown]
# ## Attributes

# %% [markdown]
# There are 29 attributes, we can divide them into 4 macro-categories:
# * People
#
#     * ID: Customer's unique identifier
#     * Year_Birth: Customer's birth year
#     * Education: Customer's education level
#     * Marital_Status: Customer's marital status
#     * Income: Customer's yearly household income
#     * Kidhome: Number of children in customer's household
#     * Teenhome: Number of teenagers in customer's household
#     * Dt_Customer: Date of customer's enrollment with the company
#     * Recency: Number of days since customer's last purchase
#     * Complain: 1 if customer complained in the last 2 years, 0 otherwise
#
# * Products
#
#     * MntWines: Amount spent on wine in last 2 years
#     * MntFruits: Amount spent on fruits in last 2 years
#     * MntMeatProducts: Amount spent on meat in last 2 years
#     * MntFishProducts: Amount spent on fish in last 2 years
#     * MntSweetProducts: Amount spent on sweets in last 2 years
#     * MntGoldProds: Amount spent on gold in last 2 years
#
# * Promotion
#
#     * NumDealsPurchases: Number of purchases made with a discount
#     * AcceptedCmp1: 1 if customer accepted the offer in the 1st campaign, 0 otherwise
#     * AcceptedCmp2: 1 if customer accepted the offer in the 2nd campaign, 0 otherwise
#     * AcceptedCmp3: 1 if customer accepted the offer in the 3rd campaign, 0 otherwise
#     * AcceptedCmp4: 1 if customer accepted the offer in the 4th campaign, 0 otherwise
#     * AcceptedCmp5: 1 if customer accepted the offer in the 5th campaign, 0 otherwise
#     * Response: 1 if customer accepted the offer in the last campaign, 0 otherwise
#
# * Place
#
#     * NumWebPurchases: Number of purchases made through the company’s web site
#     * NumCatalogPurchases: Number of purchases made using a catalogue
#     * NumStorePurchases: Number of purchases made directly in stores
#     * NumWebVisitsMonth: Number of visits to company’s web site in the last month

# %% [markdown]
# ## Exploring data (people)

# %%
import matplotlib.pyplot as plt
plt.hist(df['age'],bins="auto");

# %% [markdown]
# There are two outliers: they are probably data entry errors (human errors while collecting data). We remove them.

# %%
mask = df['age'] < 90
df = df[mask]
plt.hist(df['age'],bins="auto");

# %%
plt.hist(df['Education'],bins="auto");

# %%
plt.hist(df['Marital_Status'],bins="auto");

# %% [markdown]
# From the histogram we can see strange values such as 'Alone', 'Absurd', 'YOLO', we assume that are human errors and we can remove them without affecting our analysis.

# %%
alone = df['Marital_Status'] == 'Alone'
df = df[~alone]
absurd = df['Marital_Status'] == 'Absurd'
df = df[~absurd]
yolo =  df['Marital_Status'] == 'YOLO'
df = df[~yolo]
plt.hist(df['Marital_Status'],bins="auto");

# %%
plt.hist(df['Income'],bins="auto");

# %% [markdown]
# There's one value with income = 666666, since it's an outlier and many algorithms are sensitive to outliers we remove it.

# %%
income = df['Income'] > 200000
df = df[~income]
plt.hist(df['Income'],bins="auto");

# %%
plt.hist(df['Kidhome'],bins="auto");

# %%
plt.hist(df['Teenhome'],bins="auto");

# %%
plt.hist(df['Recency'],bins="auto");

# %%
plt.hist(df['Complain'],bins="auto");

# %% [markdown]
# ## Exploring data (Products)

# %%
plt.figure(1)
plt.hist(df['MntWines'],bins="auto");
plt.xlabel("Amount of wines purchased in last 2 years")
plt.ylabel("freq")

plt.figure(2)
plt.hist(df['MntFruits'],bins="auto");
plt.xlabel("Amount of fruits purchased in last 2 years")
plt.ylabel("freq")

plt.figure(3)
plt.hist(df['MntMeatProducts'],bins="auto");
plt.xlabel("Amount of meat purchased in last 2 years")
plt.ylabel("freq")

plt.figure(4)
plt.hist(df['MntFishProducts'],bins="auto");
plt.xlabel("Amount of fish purchased in last 2 years")
plt.ylabel("freq")

plt.figure(5)
plt.hist(df['MntSweetProducts'],bins="auto");
plt.xlabel("Amount of sweet purchased in last 2 years")
plt.ylabel("freq")

plt.figure(6)
plt.hist(df['MntGoldProds'],bins="auto");
plt.xlabel("Amount of gold purchased in last 2 years")
plt.ylabel("freq")
# Out:
# Text(0, 0.5, 'freq')

# %%
w = df['MntWines'].sum()
f = df['MntFruits'].sum()
m = df['MntMeatProducts'].sum()
fi = df['MntFishProducts'].sum()
s = df['MntSweetProducts'].sum()
g = df['MntGoldProds'].sum()
y = np.array([w,f,m,fi,s,g])
x = np.array(["Wines","Fruits","Meat","Fish","Sweet","Gold"])
plt.ylabel("Total amount spent")
plt.bar(x,y);

# %% [markdown]
# ## Exploring data (Purchases)

# %%
plt.figure(1)
plt.hist(df['NumWebPurchases'],bins="auto");
plt.xlabel("Purchases made through the web site")
plt.ylabel("freq")

plt.figure(2)
plt.hist(df['NumCatalogPurchases'],bins="auto");
plt.xlabel("Purchases made through the catalogue")
plt.ylabel("freq")

plt.figure(3)
plt.hist(df['NumStorePurchases'],bins="auto");
plt.xlabel("Purchases made in stores")
plt.ylabel("freq")

plt.figure(4)
plt.hist(df['NumWebVisitsMonth'],bins="auto");
plt.xlabel("Number of visits to company's web site in the last month")
plt.ylabel("freq")

plt.figure(5)
plt.hist((df['NumWebPurchases'].to_numpy()+df['NumStorePurchases'].to_numpy()),bins="auto");
plt.xlabel("Number of visits to company's web site in the last month")
plt.ylabel("freq")
# Out:
# Text(0, 0.5, 'freq')

# %%
plt.bar(np.array(["totNumWebPurchases","totNumStorePurchases"]),np.array([df["NumWebPurchases"].sum(), df["NumStorePurchases"].sum()]))
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# ## Preprocessing Data

# %%
df[df["Income"].isna()]
data_cleaned = df.copy()

# %% [markdown]
# ### Standard Scaler

# %%
columns_to_scale = ["Income","Kidhome", "Teenhome", "Recency", "MntWines", "MntFruits",
                  "MntMeatProducts", "MntFishProducts", "MntSweetProducts", "MntGoldProds",
                  "NumDealsPurchases", "NumWebPurchases", "NumCatalogPurchases", "NumStorePurchases", "NumWebVisitsMonth", "age"]
df_to_scale = df[columns_to_scale]

# %%
# Out:
# <AxesSubplot:>

# %%
scaler = StandardScaler()
df_scale = pd.DataFrame(scaler.fit_transform(df_to_scale), columns = columns_to_scale)
df_scale.head()
# Out:
#      Income   Kidhome  Teenhome   Recency  MntWines  MntFruits  \
# 0  0.282276 -0.826350 -0.931201  0.313400  0.975903   1.554520
# 1 -0.263617  1.039393  0.899527 -0.376940 -0.872284  -0.636079
# 2  0.905975 -0.826350 -0.931201 -0.791144  0.356879   0.572527
# 3 -1.175351  1.039393 -0.931201 -0.791144 -0.872284  -0.560541
# 4  0.289450  1.039393 -0.931201  1.556012 -0.392466   0.421452
#
#    MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# 0         1.666131         2.464957          1.462986      0.862602
# 1        -0.713963        -0.647645         -0.630813     -0.731738
# 2        -0.180645         1.348082         -0.149480     -0.031784
# 3        -0.652257        -0.501170         -0.582679     -0.751181
# 4        -0.220314         0.157970         -0.005080     -0.556749
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0           0.343988         1.415762             2.495446          -0.552040
# 1          -0.173016        -1.124609            -0.569281          -1.168872
# 2          -0.690021         1.415762            -0.228756           1.298459
# 3          -0.173016        -0.761699            -0.909807          -0.552040
# 4           1.377998         0.327032             0.111769           0.064793
#
#    NumWebVisitsMonth       age
# 0           0.687328  0.928690
# 1          -0.133247  1.356396
# 2          -0.543535  0.329902
# 3           0.277041 -1.209839
# 4          -0.133247 -0.953215

# %%
columns = ["Education","Marital_Status"]
df_to_oh = df[columns]
df_oh = pd.get_dummies(df_to_oh).reset_index()

""" concatenate the standardized dataset and the one hot encoded dataset """
df_pp = pd.concat([df_scale, df_oh], axis=1)

# %% [markdown]
# ## Association Rule: FP Growth

# %%
df_fp = pd.DataFrame()
df_fp["MntWines"] = pd.qcut(df["MntWines"], 2, labels=["low","high"]) #175 middle value
df_fp["MntFruits"] = pd.qcut(df["MntFruits"], 2, labels=["low","high"])#8 middle value
df_fp["MntMeatProducts"] = pd.qcut(df["MntMeatProducts"], 2, labels=["low","high"]) #68 middle value
df_fp["MntFishProducts"] = pd.qcut(df["MntFishProducts"], 2, labels=["low","high"]) #12 middle value
df_fp["MntSweetProducts"] = pd.qcut(df["MntSweetProducts"], 2, labels=["low","high"]) #8 middle value

df_fp = pd.get_dummies(df_fp)

# %%
'''
Filtering only consequents with MntWines_high
'''
#Apriori min support
min_support = 0.07

#Max lenght of apriori n-grams
max_len = 2

frequent_items = apriori(df_fp, use_colnames=True, min_support=min_support, max_len=max_len + 1)
rules = association_rules(frequent_items, metric='lift', min_threshold=1.5)

target = '{\'MntWines_high\'}'

results_wine = rules[(rules['consequents'].astype(str).str.contains(target, na=False)) & (rules["confidence"]>0.70)].sort_values(by='confidence', ascending=False)

results_wine
# Out:
#                                        antecedents      consequents  \
# 102  (MntMeatProducts_high, MntSweetProducts_high)  (MntWines_high)
# 76          (MntMeatProducts_high, MntFruits_high)  (MntWines_high)
# 94    (MntMeatProducts_high, MntFishProducts_high)  (MntWines_high)
# 5                           (MntMeatProducts_high)  (MntWines_high)
# 108  (MntSweetProducts_high, MntFishProducts_high)  (MntWines_high)
# 82          (MntFruits_high, MntFishProducts_high)  (MntWines_high)
# 87         (MntSweetProducts_high, MntFruits_high)  (MntWines_high)
# 72           (MntFruits_low, MntMeatProducts_high)  (MntWines_high)
# 98    (MntSweetProducts_low, MntMeatProducts_high)  (MntWines_high)
# 7                           (MntFishProducts_high)  (MntWines_high)
# 3                                 (MntFruits_high)  (MntWines_high)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 102            0.405605                 0.5  0.356441    0.878788  1.757576
# 76             0.404621                 0.5  0.354474    0.876063  1.752126
# 94             0.409538                 0.5  0.357915    0.873950  1.747899
# 5              0.496559                 0.5  0.427237    0.860396  1.720792
# 108            0.400688                 0.5  0.325959    0.813497  1.626994
# 82             0.402163                 0.5  0.325467    0.809291  1.618582
# 87             0.401672                 0.5  0.321042    0.799266  1.598531
# 72             0.091937                 0.5  0.072763    0.791444  1.582888
# 98             0.090954                 0.5  0.070796    0.778378  1.556757
# 7              0.488692                 0.5  0.371190    0.759557  1.519115
# 3              0.489184                 0.5  0.368240    0.752764  1.505528
#
#      leverage  conviction
# 102  0.153638    4.125000
# 76   0.152163    4.034314
# 94   0.153147    3.966667
# 5    0.178958    3.581560
# 108  0.125615    2.680921
# 82   0.124385    2.621795
# 87   0.120206    2.490854
# 72   0.026794    2.397436
# 98   0.025320    2.256098
# 7    0.126844    2.079498
# 3    0.123648    2.022358

# %%
'''
Filtering only consequents with MntFruits_high
'''
#Apriori min support
min_support = 0.1

#Max lenght of apriori n-grams
max_len = 2

frequent_items = apriori(df_fp, use_colnames=True, min_support=min_support, max_len=max_len + 1)
rules = association_rules(frequent_items, metric='lift', min_threshold=1.5)

target = '{\'MntFruits_high\'}'

results_fruits = rules[(rules['consequents'].astype(str).str.contains(target, na=False)) & (rules["confidence"]>0.80)].sort_values(by='confidence', ascending=False)

results_fruits
# Out:
#                                        antecedents       consequents  \
# 123   (MntMeatProducts_high, MntFishProducts_high)  (MntFruits_high)
# 75           (MntWines_high, MntFishProducts_high)  (MntFruits_high)
# 128  (MntSweetProducts_high, MntMeatProducts_high)  (MntFruits_high)
# 80          (MntSweetProducts_high, MntWines_high)  (MntFruits_high)
# 135  (MntSweetProducts_high, MntFishProducts_high)  (MntFruits_high)
# 68           (MntWines_high, MntMeatProducts_high)  (MntFruits_high)
# 17                          (MntFishProducts_high)  (MntFruits_high)
# 14                          (MntMeatProducts_high)  (MntFruits_high)
# 18                         (MntSweetProducts_high)  (MntFruits_high)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 123            0.409538            0.489184  0.361357    0.882353  1.803725
# 75             0.371190            0.489184  0.325467    0.876821  1.792416
# 128            0.405605            0.489184  0.354474    0.873939  1.786525
# 80             0.369223            0.489184  0.321042    0.869507  1.777465
# 135            0.400688            0.489184  0.347591    0.867485  1.773330
# 68             0.427237            0.489184  0.354474    0.829689  1.696068
# 17             0.488692            0.489184  0.402163    0.822938  1.682266
# 14             0.496559            0.489184  0.404621    0.814851  1.665737
# 18             0.493609            0.489184  0.401672    0.813745  1.663475
#
#      leverage  conviction
# 123  0.161018    4.341937
# 75   0.143887    4.146948
# 128  0.156059    4.052147
# 80   0.140424    3.914519
# 135  0.151581    3.854770
# 68   0.145477    2.999319
# 17   0.163103    2.884950
# 14   0.161713    2.758953
# 18   0.160206    2.742564

# %%
'''
Filtering only consequents with MntMeatProducts_high
'''
#Apriori min support
min_support = 0.1

#Max lenght of apriori n-grams
max_len = 2

frequent_items = apriori(df_fp, use_colnames=True, min_support=min_support, max_len=max_len + 1)
rules = association_rules(frequent_items, metric='lift', min_threshold=1.5)

target = '{\'MntMeatProducts_high\'}'

results_meat = rules[(rules['consequents'].astype(str).str.contains(target, na=False)) & (rules["confidence"]>0.80)].sort_values(by='confidence', ascending=False)

results_meat
# Out:
#                                        antecedents             consequents  \
# 93          (MntWines_high, MntSweetProducts_high)  (MntMeatProducts_high)
# 87           (MntWines_high, MntFishProducts_high)  (MntMeatProducts_high)
# 69                 (MntWines_high, MntFruits_high)  (MntMeatProducts_high)
# 147  (MntSweetProducts_high, MntFishProducts_high)  (MntMeatProducts_high)
# 124         (MntFruits_high, MntFishProducts_high)  (MntMeatProducts_high)
# 129        (MntSweetProducts_high, MntFruits_high)  (MntMeatProducts_high)
# 4                                  (MntWines_high)  (MntMeatProducts_high)
# 25                          (MntFishProducts_high)  (MntMeatProducts_high)
# 15                                (MntFruits_high)  (MntMeatProducts_high)
# 26                         (MntSweetProducts_high)  (MntMeatProducts_high)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 93             0.369223            0.496559  0.356441    0.965379  1.944140
# 87             0.371190            0.496559  0.357915    0.964238  1.941843
# 69             0.368240            0.496559  0.354474    0.962617  1.938577
# 147            0.400688            0.496559  0.360865    0.900613  1.813711
# 124            0.402163            0.496559  0.361357    0.898533  1.809521
# 129            0.401672            0.496559  0.354474    0.882497  1.777227
# 4              0.500000            0.496559  0.427237    0.854474  1.720792
# 25             0.488692            0.496559  0.409538    0.838028  1.687673
# 15             0.489184            0.496559  0.404621    0.827136  1.665737
# 26             0.493609            0.496559  0.405605    0.821713  1.654816
#
#      leverage  conviction
# 93   0.173100   14.541714
# 87   0.173598   14.077716
# 69   0.171621   13.467060
# 147  0.161900    5.065492
# 124  0.161659    4.961628
# 129  0.155021    4.284497
# 4    0.178958    3.459459
# 25   0.166874    3.108204
# 15   0.161713    2.912351
# 26   0.160499    2.823772

# %%
'''
Filtering only consequents with MntFishProducts_high
'''
#Apriori min support
min_support = 0.1

#Max lenght of apriori n-grams
max_len = 2

frequent_items = apriori(df_fp, use_colnames=True, min_support=min_support, max_len=max_len + 1)
rules = association_rules(frequent_items, metric='lift', min_threshold=1.5)

target = '{\'MntFishProducts_high\'}'

results_fish = rules[(rules['consequents'].astype(str).str.contains(target, na=False)) & (rules["confidence"]>0.80)].sort_values(by='confidence', ascending=False)

results_fish
# Out:
#                                        antecedents             consequents  \
# 122         (MntMeatProducts_high, MntFruits_high)  (MntFishProducts_high)
# 146  (MntSweetProducts_high, MntMeatProducts_high)  (MntFishProducts_high)
# 74                 (MntWines_high, MntFruits_high)  (MntFishProducts_high)
# 98          (MntWines_high, MntSweetProducts_high)  (MntFishProducts_high)
# 134        (MntSweetProducts_high, MntFruits_high)  (MntFishProducts_high)
# 86           (MntWines_high, MntMeatProducts_high)  (MntFishProducts_high)
# 24                          (MntMeatProducts_high)  (MntFishProducts_high)
# 16                                (MntFruits_high)  (MntFishProducts_high)
# 30                         (MntSweetProducts_high)  (MntFishProducts_high)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 122            0.404621            0.488692  0.361357    0.893074  1.827478
# 146            0.405605            0.488692  0.360865    0.889697  1.820567
# 74             0.368240            0.488692  0.325467    0.883845  1.808593
# 98             0.369223            0.488692  0.325959    0.882823  1.806501
# 134            0.401672            0.488692  0.347591    0.865361  1.770769
# 86             0.427237            0.488692  0.357915    0.837745  1.714258
# 24             0.496559            0.488692  0.409538    0.824752  1.687673
# 16             0.489184            0.488692  0.402163    0.822111  1.682266
# 30             0.493609            0.488692  0.400688    0.811753  1.661072
#
#      leverage  conviction
# 122  0.163622    4.781890
# 146  0.162649    4.635483
# 74   0.145511    4.401948
# 98   0.145522    4.363547
# 134  0.151297    3.797622
# 86   0.149128    3.151251
# 24   0.166874    2.917632
# 16   0.163103    2.874301
# 30   0.159466    2.716153

# %%
'''
Filtering only consequents with MntSweetProducts_high
'''
#Apriori min support
min_support = 0.1

#Max lenght of apriori n-grams
max_len = 2

frequent_items = apriori(df_fp, use_colnames=True, min_support=min_support, max_len=max_len + 1)
rules = association_rules(frequent_items, metric='lift', min_threshold=1.5)

target = '{\'MntSweetProducts_high\'}'

results_sweet = rules[(rules['consequents'].astype(str).str.contains(target, na=False)) & (rules["confidence"]>0.80)].sort_values(by='confidence', ascending=False)

results_sweet
# Out:
#                                       antecedents              consequents  \
# 148  (MntMeatProducts_high, MntFishProducts_high)  (MntSweetProducts_high)
# 99          (MntWines_high, MntFishProducts_high)  (MntSweetProducts_high)
# 130        (MntMeatProducts_high, MntFruits_high)  (MntSweetProducts_high)
# 82                (MntWines_high, MntFruits_high)  (MntSweetProducts_high)
# 136        (MntFruits_high, MntFishProducts_high)  (MntSweetProducts_high)
# 92          (MntWines_high, MntMeatProducts_high)  (MntSweetProducts_high)
# 19                               (MntFruits_high)  (MntSweetProducts_high)
# 31                         (MntFishProducts_high)  (MntSweetProducts_high)
# 27                         (MntMeatProducts_high)  (MntSweetProducts_high)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 148            0.409538            0.493609  0.360865    0.881152  1.785124
# 99             0.371190            0.493609  0.325959    0.878146  1.779032
# 130            0.404621            0.493609  0.354474    0.876063  1.774813
# 82             0.368240            0.493609  0.321042    0.871829  1.766235
# 136            0.402163            0.493609  0.347591    0.864303  1.750989
# 92             0.427237            0.493609  0.356441    0.834292  1.690190
# 19             0.489184            0.493609  0.401672    0.821106  1.663475
# 31             0.488692            0.493609  0.400688    0.819920  1.661072
# 27             0.496559            0.493609  0.405605    0.816832  1.654816
#
#      leverage  conviction
# 148  0.158714    4.260848
# 99   0.142736    4.155712
# 130  0.154749    4.085883
# 82   0.139276    3.950907
# 136  0.149080    3.731785
# 92   0.145553    3.055931
# 19   0.160206    2.830671
# 31   0.159466    2.812028
# 27   0.160499    2.764623

# %%
df["age"] = pd.qcut(df["age"], 3, labels=["<=38", ">38 <=49",">49"])
df["Income"] = pd.qcut(df["Income"], 3, labels=["<=40521",">40521 <=62905",">62905"])

# %%
df_fp = df[["age", "Income", "MntWines", "Marital_Status", "Education"]]
df_fp = pd.get_dummies(df_fp)

# %%
#Apriori min support
min_support = 0.05

#Max lenght of apriori n-grams
max_len = 5

frequent_items = apriori(df_fp, use_colnames=True, min_support=min_support, max_len=max_len + 1)
rules = association_rules(frequent_items, metric='lift', min_threshold=1)

rules.head(10).sort_values(by='confidence', ascending=False)
# Out:
#                 antecedents               consequents  antecedent support  \
# 9                (age_<=38)    (Education_Graduation)            0.349975
# 1          (Income_<=40521)                (age_<=38)            0.333663
# 2           (MntWines_<=46)                (age_<=38)            0.337123
# 0                (age_<=38)          (Income_<=40521)            0.349975
# 3                (age_<=38)           (MntWines_<=46)            0.349975
# 6   (Marital_Status_Single)                (age_<=38)            0.216510
# 5                (age_<=38)  (Marital_Status_Married)            0.349975
# 8    (Education_Graduation)                (age_<=38)            0.502224
# 4  (Marital_Status_Married)                (age_<=38)            0.389521
# 7                (age_<=38)   (Marital_Status_Single)            0.349975
#
#    consequent support   support  confidence      lift  leverage  conviction
# 9            0.502224  0.184874    0.528249  1.051818  0.009108    1.055165
# 1            0.349975  0.164607    0.493333  1.409623  0.047833    1.282944
# 2            0.349975  0.160158    0.475073  1.357448  0.042173    1.238315
# 0            0.333663  0.164607    0.470339  1.409623  0.047833    1.258044
# 3            0.337123  0.160158    0.457627  1.357448  0.042173    1.222179
# 6            0.349975  0.094909    0.438356  1.252535  0.019135    1.157361
# 5            0.389521  0.142363    0.406780  1.044309  0.006040    1.029094
# 8            0.349975  0.184874    0.368110  1.051818  0.009108    1.028700
# 4            0.349975  0.142363    0.365482  1.044309  0.006040    1.024439
# 7            0.216510  0.094909    0.271186  1.252535  0.019135    1.075021

# %%
'''
Filtering only consequents with MntWines<=46
'''

#Apriori min support
min_support = 0.05

#Max lenght of apriori n-grams
max_len = 3

frequent_items = apriori(df_fp, use_colnames=True, min_support=min_support, max_len=max_len + 1)
rules = association_rules(frequent_items, metric='lift', min_threshold=1)

target = '{\'MntWines_<=46\'}'

results_attrition_no = rules[rules['consequents'].astype(str).str.contains(target, na=False)].sort_values(by='confidence', ascending=False)

results_attrition_no
# Out:
#                                            antecedents      consequents  \
# 305  (Marital_Status_Married, Education_Graduation,...  (MntWines_<=46)
# 294   (Education_Graduation, age_<=38, Income_<=40521)  (MntWines_<=46)
# 217             (Education_Graduation, Income_<=40521)  (MntWines_<=46)
# 90                          (age_<=38, Income_<=40521)  (MntWines_<=46)
# 199           (Marital_Status_Married, Income_<=40521)  (MntWines_<=46)
# 280  (Marital_Status_Married, age_<=38, Income_<=40...  (MntWines_<=46)
# 130                     (age_>38 <=49, Income_<=40521)  (MntWines_<=46)
# 212          (Income_<=40521, Marital_Status_Together)  (MntWines_<=46)
# 37                                    (Income_<=40521)  (MntWines_<=46)
# 205            (Marital_Status_Single, Income_<=40521)  (MntWines_<=46)
# 3                                           (age_<=38)  (MntWines_<=46)
# 111                 (Marital_Status_Married, age_<=38)  (MntWines_<=46)
# 117                   (Education_Graduation, age_<=38)  (MntWines_<=46)
# 157               (Education_Graduation, age_>38 <=49)  (MntWines_<=46)
# 268     (Marital_Status_Married, Education_Graduation)  (MntWines_<=46)
# 13                                      (age_>38 <=49)  (MntWines_<=46)
# 60                             (Marital_Status_Single)  (MntWines_<=46)
# 58                            (Marital_Status_Married)  (MntWines_<=46)
# 63                           (Marital_Status_Together)  (MntWines_<=46)
# 64                              (Education_Graduation)  (MntWines_<=46)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 305            0.066733            0.337123  0.059812    0.896296  2.658662
# 294            0.081068            0.337123  0.069204    0.853659  2.532187
# 217            0.166584            0.337123  0.141869    0.851632  2.526175
# 90             0.164607            0.337123  0.139891    0.849850  2.520889
# 199            0.132477            0.337123  0.110727    0.835821  2.479275
# 280            0.069204            0.337123  0.057835    0.835714  2.478959
# 130            0.105289            0.337123  0.087000    0.826291  2.451007
# 212            0.085022            0.337123  0.070193    0.825581  2.448902
# 37             0.333663            0.337123  0.274839    0.823704  2.443332
# 205            0.080079            0.337123  0.061295    0.765432  2.270483
# 3              0.349975            0.337123  0.160158    0.457627  1.357448
# 111            0.142363            0.337123  0.063767    0.447917  1.328644
# 117            0.184874            0.337123  0.080573    0.435829  1.292789
# 157            0.159170            0.337123  0.057341    0.360248  1.068596
# 268            0.193772            0.337123  0.067721    0.349490  1.036683
# 13             0.318833            0.337123  0.110727    0.347287  1.030148
# 60             0.216510            0.337123  0.075136    0.347032  1.029392
# 58             0.389521            0.337123  0.134948    0.346447  1.027656
# 63             0.253089            0.337123  0.086505    0.341797  1.013864
# 64             0.502224            0.337123  0.169550    0.337598  1.001410
#
#      leverage  conviction
# 305  0.037315    6.392027
# 294  0.041874    4.529659
# 217  0.085709    4.467790
# 90   0.084398    4.414760
# 199  0.066066    4.037523
# 280  0.034505    4.034903
# 130  0.051504    3.816021
# 212  0.041530    3.800494
# 37   0.162354    3.760016
# 205  0.034299    2.825949
# 3    0.042173    1.222179
# 111  0.015773    1.200683
# 117  0.018248    1.174957
# 157  0.003681    1.036147
# 268  0.002396    1.019011
# 13   0.003241    1.015572
# 60   0.002145    1.015175
# 58   0.003632    1.014266
# 63   0.001183    1.007101
# 64   0.000239    1.000718

# %%
'''
Filtering only consequents with MntWines_>46 <=378
'''

#Apriori min support
min_support = 0.1

#Max lenght of apriori n-grams
max_len = 4

frequent_items = apriori(df_fp, use_colnames=True, min_support=min_support, max_len=max_len + 1)
rules = association_rules(frequent_items, metric='lift', min_threshold=1)

target = '{\'MntWines_>46 <=378\'}'

results_attrition_no = rules[rules['consequents'].astype(str).str.contains(target, na=False)].sort_values(by='confidence', ascending=False)

results_attrition_no
# Out:
#                  antecedents           consequents  antecedent support  \
# 29   (Income_>40521 <=62905)  (MntWines_>46 <=378)            0.333169
# 21                 (age_>49)  (MntWines_>46 <=378)            0.331191
# 40    (Education_Graduation)  (MntWines_>46 <=378)            0.502224
# 38  (Marital_Status_Married)  (MntWines_>46 <=378)            0.389521
# 13            (age_>38 <=49)  (MntWines_>46 <=378)            0.318833
#
#     consequent support   support  confidence      lift  leverage  conviction
# 29            0.329708  0.186357    0.559347  1.696491  0.076508    1.521133
# 21            0.329708  0.124073    0.374627  1.136237  0.014877    1.071827
# 40            0.329708  0.174988    0.348425  1.056768  0.009400    1.028726
# 38            0.329708  0.129016    0.331218  1.004580  0.000588    1.002258
# 13            0.329708  0.105289    0.330233  1.001590  0.000167    1.000783

# %%
'''
Filtering only consequents with MntWines_>378
'''

#Apriori min support
min_support = 0.1

#Max lenght of apriori n-grams
max_len = 4

frequent_items = apriori(df_fp, use_colnames=True, min_support=min_support, max_len=max_len + 1)
rules = association_rules(frequent_items, metric='lift', min_threshold=1)

target = '{\'MntWines_>378\'}'

results_attrition_no = rules[rules['consequents'].astype(str).str.contains(target, na=False)].sort_values(by='confidence', ascending=False)

results_attrition_no
# Out:
#                               antecedents      consequents  \
# 52               (Income_>62905, age_>49)  (MntWines_>378)
# 31                        (Income_>62905)  (MntWines_>378)
# 69  (Income_>62905, Education_Graduation)  (MntWines_>378)
# 23                              (age_>49)  (MntWines_>378)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 52            0.136431            0.333169  0.103312    0.757246  2.272863
# 31            0.333169            0.333169  0.245180    0.735905  2.208807
# 69            0.175482            0.333169  0.121602    0.692958  2.079901
# 23            0.331191            0.333169  0.140880    0.425373  1.276751
#
#     leverage  conviction
# 52  0.057857    2.746947
# 31  0.134179    2.524968
# 69  0.063137    2.171790
# 23  0.030537    1.160460

# %%
df_tot = data_cleaned.copy()
df_tot["TotalSpending"] = df_tot["MntWines"] + df_tot["MntFruits"] + df_tot["MntFishProducts"] + df_tot["MntSweetProducts"] + df_tot["MntGoldProds"]
df_tot.drop(inplace=True, columns=["MntWines", "MntFruits", "MntMeatProducts", "MntFishProducts", "MntSweetProducts", "MntGoldProds"])

# %%
df_tot["TotalSpending"] = pd.qcut(df_tot["TotalSpending"], 3, labels=["<=106", ">106 <=790", ">790"])
df_tot["age"] = pd.qcut(df_tot["age"], 3, labels=["<=38", ">38 <=49",">49"])
df_tot["Income"] = pd.qcut(df_tot["Income"], 3, labels=["<=40521",">40521 <=62905",">62905"])

# %%
df_fp = df_tot[["age", "Income", "TotalSpending", "Marital_Status", "Education", "Has_child"]]
df_fp = pd.get_dummies(df_fp)

# %%
'''
Filtering only consequents with TotalSpending_<=106
'''
#Apriori min support
min_support = 0.08

#Max lenght of apriori n-grams
max_len = 3

frequent_items = apriori(df_fp, use_colnames=True, min_support=min_support, max_len=max_len + 1)
rules = association_rules(frequent_items, metric='lift', min_threshold=1.5)

target = '{\'TotalSpending_<=106\'}'

results_tot_low = rules[(rules['consequents'].astype(str).str.contains(target, na=False)) & (rules["confidence"]>0.8)].sort_values(by='confidence', ascending=False)

results_tot_low
# Out:
#                                            antecedents            consequents  \
# 145      (age_>38 <=49, Has_child_yes, Income_<=40521)  (TotalSpending_<=106)
# 19                      (age_>38 <=49, Income_<=40521)  (TotalSpending_<=106)
# 119          (Has_child_yes, Income_<=40521, age_<=38)  (TotalSpending_<=106)
# 103  (Income_<=40521, Marital_Status_couple, age_<=38)  (TotalSpending_<=106)
# 49                     (Has_child_yes, Income_<=40521)  (TotalSpending_<=106)
# 173  (Has_child_yes, Income_<=40521, Marital_Status...  (TotalSpending_<=106)
# 181  (Has_child_yes, Income_<=40521, Education_Post...  (TotalSpending_<=106)
# 11                          (Income_<=40521, age_<=38)  (TotalSpending_<=106)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 145            0.096362            0.333825  0.080629    0.836735  2.506507
# 19             0.105211            0.333825  0.086529    0.822430  2.463656
# 119            0.141101            0.333825  0.115536    0.818815  2.452828
# 103            0.108161            0.333825  0.088496    0.818182  2.450931
# 49             0.285152            0.333825  0.233038    0.817241  2.448113
# 173            0.187807            0.333825  0.153392    0.816754  2.446653
# 181            0.238938            0.333825  0.193707    0.810700  2.428517
# 11             0.164208            0.333825  0.131760    0.802395  2.403640
#
#      leverage  conviction
# 145  0.048461    4.080322
# 19   0.051407    3.751617
# 119  0.068433    3.676774
# 103  0.052389    3.663963
# 49   0.137847    3.645109
# 173  0.090698    3.635412
# 181  0.113943    3.519142
# 11   0.076943    3.371249

# %%
'''
Filtering only consequents with TotalSpending_>106 <=790
'''

#Apriori min support
min_support = 0.08

#Max lenght of apriori n-grams
max_len = 3

frequent_items = fpgrowth(df_fp, use_colnames=True, min_support=min_support, max_len=max_len + 1)
rules = association_rules(frequent_items, metric='lift', min_threshold=1.5)

target = '{\'TotalSpending_>106 <=790\'}'

results_tot_medium = rules[(rules['consequents'].astype(str).str.contains(target, na=False)) & (rules["confidence"]>0.6)].sort_values(by='confidence', ascending=False)

results_tot_medium
# Out:
#                                           antecedents  \
# 99                   (age_>49, Income_>40521 <=62905)
# 15  (Has_child_yes, Education_Postgraduate, Income...
#
#                    consequents  antecedent support  consequent support  \
# 99  (TotalSpending_>106 <=790)            0.131268            0.333825
# 15  (TotalSpending_>106 <=790)            0.274336            0.333825
#
#      support  confidence      lift  leverage  conviction
# 99  0.080138    0.610487  1.828763  0.036317    1.710276
# 15  0.164700    0.600358  1.798423  0.073120    1.666931

# %%
'''
Filtering only consequents with TotalSpending_>790
'''

#Apriori min support
min_support = 0.08

#Max lenght of apriori n-grams
max_len = 3

frequent_items = fpgrowth(df_fp, use_colnames=True, min_support=min_support, max_len=max_len + 1)
rules = association_rules(frequent_items, metric='lift', min_threshold=1.5)

target = '{\'TotalSpending_>790\'}'

results_tot_high = rules[(rules['consequents'].astype(str).str.contains(target, na=False)) & (rules["confidence"]>0.8)].sort_values(by='confidence', ascending=False)
results_tot_high
#rules.loc[122]
# Out:
#                                            antecedents           consequents  \
# 118  (Education_Postgraduate, Income_>62905, Has_ch...  (TotalSpending_>790)
# 112                      (Income_>62905, Has_child_no)  (TotalSpending_>790)
# 154  (Marital_Status_couple, Income_>62905, Has_chi...  (TotalSpending_>790)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 118            0.181908             0.33235  0.153884    0.845946  2.545346
# 112            0.198623             0.33235  0.167158    0.841584  2.532222
# 154            0.120944             0.33235  0.101278    0.837398  2.519628
#
#      leverage  conviction
# 118  0.093427    4.333868
# 112  0.101146    4.214540
# 154  0.061083    4.106047

# %%
df_tot["TotalSpending"] = pd.qcut(df_tot["TotalSpending"], 3, labels=["<=106", ">106 <=790", ">790"])
df["age"] = pd.qcut(df["age"], 3, labels=["<=38", ">38 <=49",">49"])
df["Income"] = pd.qcut(df["Income"], 3, labels=["<=40521",">40521 <=62905",">62905"])

# %%
df_fp = df_tot[["age", "Income", "TotalSpending", "Marital_Status", "Education"]]
df_fp = pd.get_dummies(df_fp)

# %%
'''
Filtering only consequents with TotalSpending_<=106
'''

#Apriori min support
min_support = 0.08

#Max lenght of apriori n-grams
max_len = 3

frequent_items = apriori(df_fp, use_colnames=True, min_support=min_support, max_len=max_len + 1)
rules = association_rules(frequent_items, metric='lift', min_threshold=1.5)

target = '{\'TotalSpending_<=106\'}'

results_tot_low = rules[rules['consequents'].astype(str).str.contains(target, na=False)].sort_values(by='confidence', ascending=False)

results_tot_low
# Out:
#                                  antecedents            consequents  \
# 11            (age_>38 <=49, Income_<=40521)  (TotalSpending_<=106)
# 27    (Education_Graduation, Income_<=40521)  (TotalSpending_<=106)
# 7                 (Income_<=40521, age_<=38)  (TotalSpending_<=106)
# 23  (Marital_Status_Married, Income_<=40521)  (TotalSpending_<=106)
# 1                           (Income_<=40521)  (TotalSpending_<=106)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 11            0.105289            0.336134  0.087494    0.830986  2.472183
# 27            0.166584            0.336134  0.135442    0.813056  2.418843
# 7             0.164607            0.336134  0.133465    0.810811  2.412162
# 23            0.132477            0.336134  0.106772    0.805970  2.397761
# 1             0.333663            0.336134  0.267425    0.801481  2.384407
#
#     leverage  conviction
# 11  0.052103    3.927871
# 27  0.079448    3.551154
# 7   0.078135    3.509004
# 23  0.062242    3.421461
# 1   0.155269    3.344099

# %%
'''
Filtering only consequents with TotalSpending_>106 <=790
'''

#Apriori min support
min_support = 0.08

#Max lenght of apriori n-grams
max_len = 3

frequent_items = fpgrowth(df_fp, use_colnames=True, min_support=min_support, max_len=max_len + 1)
rules = association_rules(frequent_items, metric='lift', min_threshold=1.5)

target = '{\'TotalSpending_>106 <=790\'}'

results_tot_medium = rules[rules['consequents'].astype(str).str.contains(target, na=False)].sort_values(by='confidence', ascending=False)

results_tot_medium
# Out:
#                                       antecedents                 consequents  \
# 39  (Education_Graduation, Income_>40521 <=62905)  (TotalSpending_>106 <=790)
# 15               (age_>49, Income_>40521 <=62905)  (TotalSpending_>106 <=790)
# 37                        (Income_>40521 <=62905)  (TotalSpending_>106 <=790)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 39            0.160158            0.331191  0.100346    0.626543  1.891786
# 15            0.130994            0.331191  0.080079    0.611321  1.845824
# 37            0.333169            0.331191  0.194760    0.584570  1.765052
#
#     leverage  conviction
# 39  0.047303    1.790860
# 15  0.036695    1.720721
# 37  0.084418    1.609918

# %%
'''
Filtering only consequents with TotalSpending_>790
'''

#Apriori min support
min_support = 0.08

#Max lenght of apriori n-grams
max_len = 3

frequent_items = fpgrowth(df_fp, use_colnames=True, min_support=min_support, max_len=max_len + 1)
rules = association_rules(frequent_items, metric='lift', min_threshold=1.5)

target = '{\'TotalSpending_>790\'}'

results_tot_high = rules[rules['consequents'].astype(str).str.contains(target, na=False)].sort_values(by='confidence', ascending=False)

results_tot_high
# Out:
#                                 antecedents           consequents  \
# 11                 (age_>49, Income_>62905)  (TotalSpending_>790)
# 1                           (Income_>62905)  (TotalSpending_>790)
# 3     (Education_Graduation, Income_>62905)  (TotalSpending_>790)
# 7   (Marital_Status_Married, Income_>62905)  (TotalSpending_>790)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 11            0.136431            0.332674  0.107761    0.789855  2.374260
# 1             0.333169            0.332674  0.260010    0.780415  2.345885
# 3             0.175482            0.332674  0.135937    0.774648  2.328548
# 7             0.128522            0.332674  0.094909    0.738462  2.219774
#
#     leverage  conviction
# 11  0.062374    3.175550
# 1   0.149173    3.039038
# 3   0.077558    2.961258
# 7   0.052153    2.551540
